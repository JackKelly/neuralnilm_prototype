# %%
from __future__ import print_function, division
import matplotlib
matplotlib.use('nbagg') # interactive plots in iPython. New in matplotlib v1.4
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from nilmtk import DataSet, MeterGroup
import pandas as pd
import numpy as np
from time import time
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# /usr/local/lib/python2.7/dist-packages/bottleneck/__init__.py:13: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from .func import (nansum, nanmax, nanmin, nanmean, nanstd, nanvar, median,
# /usr/local/lib/python2.7/dist-packages/bottleneck/__init__.py:19: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility
#   from .move import (move_sum, move_nansum,

# %%
from pybrain.supervised import RPropMinusTrainer
from pybrain.datasets import SequentialDataSet
from pybrain.structure import RecurrentNetwork, FullConnection
from pybrain.structure.modules import LSTMLayer, BiasUnit, LinearLayer, TanhLayer, SigmoidLayer

# %%
CONFIG = dict(
    EPOCHS_PER_CYCLE = 5,
    CYCLES = 10,
    HIDDEN_LAYERS = [10, 10, 10],
    PEEPHOLES = True,
    TRAINERCLASS = RPropMinusTrainer,
    # instead, you may also try
    # TRAINERCLASS = BackpropTrainer(net, dataset=trndata, verbose=True, 
    #                                momentum=0.9, learningrate=0.00001)
    INPUTS = ['fridge'] #, 'hour of day (int)', 'outside temperature', 'is business day (-1, 1)'
)

# %%
# Load dataset
dataset = DataSet('/data/mine/vadeec/merged/ukdale.h5')
dataset.set_window("2014-01-01", "2014-02-01")
elec = dataset.buildings[1].elec

# %%
# Select top-5 meters identified in UK-DALE paper
# APPLIANCES = ['kettle', 'dish washer', 'HTPC', 'washer dryer', 'fridge freezer']
APPLIANCES = ['fridge freezer']
selected_meters = [elec[appliance] for appliance in APPLIANCES]
selected_meters.append(elec.mains())
selected = MeterGroup(selected_meters)

# %%
df = selected.dataframe_of_meters()

# %%
# Use human-readable column names
df.columns = selected.get_labels(df.columns)

# %%
#df.plot()
#plt.show()

# %%
# neural networks like data to be standardised
# df['Fridge freezer'] = df['Fridge freezer'].clip(0, 150)
#ptp = (df.min() - df.max()).abs()
#rescaled = (df - df.mean()) / ptp
#df = rescaled

# %%
#df.plot()
#plt.show()

# %%
mains = df['Site meter']
appliances = df.iloc[:,:-1].fillna(0)
del df

# %%
# standardise input
mains = (mains - mains.mean()) / mains.std()

# Constrain outputs to [0,1] because we're using Sigmoid
appliances /= appliances.max()

# %%
mains.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
appliances.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# Build PyBrain dataset
N_OUTPUTS = appliances.shape[1]
N_INPUTS = 1
N = len(mains)
ds = SequentialDataSet(N_INPUTS, N_OUTPUTS)
ds.newSequence()
ds.setField('input', pd.DataFrame(mains).values)
ds.setField('target', appliances.values)

# %%
ds.getSequence(0)
# Out:
# /usr/local/lib/python2.7/dist-packages/PyBrain-0.3.3-py2.7.egg/pybrain/datasets/sequential.py:45: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return self.getField(field)[seq[index]:]
# [array([[ 0.33269537],
#         [ 0.34341707],
#         [ 0.342669  ],
#         ...,
#         [ 0.20100178],
#         [ 0.19980159],
#         [ 0.19954161]]), array([[ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         ...,
#         [ 0.05243243],
#         [ 0.05243243],
#         [ 0.05243243]])]

# %%
# Build network
net = RecurrentNetwork()

def lstm_layer_name(i):
    return 'LSTM{:d}'.format(i)

# Add modules
net.addInputModule(LinearLayer(ds.indim, name='in'))
net.addOutputModule(SigmoidLayer(dim=ds.outdim, name='out'))
for i, n_cells in enumerate(CONFIG['HIDDEN_LAYERS']):
    net.addModule(LSTMLayer(n_cells, name=lstm_layer_name(i+1), peepholes=CONFIG['PEEPHOLES']))   

# Bias
bias = BiasUnit()
net.addModule(bias)
net.addConnection(FullConnection(bias, net['out'], name='c_output_bias'))
    
# Add connections

n_hidden_layers = len(CONFIG['HIDDEN_LAYERS'])
prev_layer_name = 'in'
for i in range(n_hidden_layers):
    hidden_layer_i = i + 1
    layer_name = lstm_layer_name(hidden_layer_i)
    net.addRecurrentConnection(FullConnection(net[layer_name], net[layer_name], name='c_' + layer_name + '_to_' + layer_name))
    net.addConnection(FullConnection(bias, net[layer_name], name='c_' + layer_name + '_bias'))
    net.addConnection(FullConnection(net[prev_layer_name], net[layer_name], name='c_' + prev_layer_name + '_to_' + layer_name))
    prev_layer_name = layer_name
    
layer_name = lstm_layer_name(n_hidden_layers)
net.addConnection(FullConnection(net[layer_name], net['out'], name='c_' + layer_name + '_to_out'))

net.sortModules()
print(net)
# Out:
# RecurrentNetwork-7
#    Modules:
#     [<BiasUnit 'BiasUnit-6'>, <LinearLayer 'in'>, <LSTMLayer 'LSTM1'>, <LSTMLayer 'LSTM2'>, <LSTMLayer 'LSTM3'>, <SigmoidLayer 'out'>]
#    Connections:
#     [<FullConnection 'c_LSTM1_bias': 'BiasUnit-6' -> 'LSTM1'>, <FullConnection 'c_LSTM1_to_LSTM2': 'LSTM1' -> 'LSTM2'>, <FullConnection 'c_LSTM2_bias': 'BiasUnit-6' -> 'LSTM2'>, <FullConnection 'c_LSTM2_to_LSTM3': 'LSTM2' -> 'LSTM3'>, <FullConnection 'c_LSTM3_bias': 'BiasUnit-6' -> 'LSTM3'>, <FullConnection 'c_LSTM3_to_out': 'LSTM3' -> 'out'>, <FullConnection 'c_in_to_LSTM1': 'in' -> 'LSTM1'>, <FullConnection 'c_output_bias': 'BiasUnit-6' -> 'out'>]
#    Recurrent Connections:
#     [<FullConnection 'c_LSTM1_to_LSTM1': 'LSTM1' -> 'LSTM1'>, <FullConnection 'c_LSTM2_to_LSTM2': 'LSTM2' -> 'LSTM2'>, <FullConnection 'c_LSTM3_to_LSTM3': 'LSTM3' -> 'LSTM3'>]

# %%
# define a training method
net.randomize()
net._setParameters(np.random.uniform(-0.1, 0.1, size=net.paramdim))
trainer = CONFIG['TRAINERCLASS'](net, dataset=ds, verbose=True)

# %%
# carry out the training
net.reset()
# train_errors = []
t0 = time()
EPOCHS = CONFIG['EPOCHS_PER_CYCLE'] * CONFIG['CYCLES']
# trainer.trainUntilConvergence(maxEpochs=EPOCHS, verbose=True)
# start_time = time()
print("Starting training with", EPOCHS, "epochs...")
for i in xrange(CONFIG['CYCLES']):
    trainer.trainEpochs(CONFIG['EPOCHS_PER_CYCLE'])
#    train_errors.append(trainer.testOnData())
    # epoch = (i+1) * CONFIG['EPOCHS_PER_CYCLE']
    # seconds_elapsed = time() - start_time
    # seconds_per_epoch = seconds_elapsed / epoch
    # seconds_remaining = (EPOCHS - epoch) * seconds_per_epoch
    # td_elapsed = timedelta(seconds=seconds_elapsed)
    # td_elapsed_str = str(td_elapsed).split('.')[0]
    # eta = (datetime.now() + timedelta(seconds=seconds_remaining)).time()
    # eta = eta.strftime("%H:%M:%S")
    # print("\r epoch = {}/{}    error = {}  elapsed = {}   ETA = {}"
    #       .format(epoch, EPOCHS, train_errors[-1], td_elapsed_str, eta),
    #       end="")
    # stdout.flush()
print("Finished training.  total seconds =", time() - t0)
# Out:
# Starting training with 50 epochs...
# epoch      0  total error      0.11721   avg weight      0.057533
# epoch      1  total error     0.086492   avg weight       0.11583
# epoch      2  total error      0.01415   avg weight       0.15987
# epoch      3  total error    0.0034187   avg weight       0.22205
# epoch      4  total error   0.00056214   avg weight       0.30378
# epoch      5  total error   0.00047903   avg weight       0.39176
# epoch      6  total error    0.0007873   avg weight       0.45291
# epoch      7  total error   0.00041342   avg weight       0.53346
# epoch      8  total error   0.00047904   avg weight       0.65603
# epoch      9  total error   0.00042536   avg weight       0.80498
# epoch     10  total error    0.0004286   avg weight       0.95814
# epoch     11  total error   0.00042518   avg weight        1.1384
# epoch     12  total error   0.00041425   avg weight        1.3669
# epoch     13  total error   0.00041944   avg weight        1.5826
# epoch     14  total error   0.00041287   avg weight        1.7654
# epoch     15  total error   0.00041515   avg weight        1.9603
# epoch     16  total error   0.00041314   avg weight        2.1515
# epoch     17  total error   0.00041314   avg weight        2.2777
# epoch     18  total error   0.00041533   avg weight        2.3541
# epoch     19  total error    0.0004132   avg weight        2.4376
# epoch     20  total error   0.00041312   avg weight        2.5397
# epoch     21  total error   0.00041268   avg weight        2.6794
# epoch     22  total error   0.00041292   avg weight        2.7476
# epoch     23  total error   0.00041294   avg weight        2.8377
# epoch     24  total error   0.00041243   avg weight        2.9678
# epoch     25  total error   0.00041362   avg weight        3.1484
# epoch     26  total error   0.00041259   avg weight        3.2225
# epoch     27  total error   0.00041305   avg weight        3.2572
# epoch     28  total error   0.00041275   avg weight        3.2622
# epoch     29  total error   0.00041274   avg weight        3.2797
# epoch     30  total error   0.00041236   avg weight        3.3026
# epoch     31  total error   0.00041226   avg weight        3.3075
# epoch     32  total error   0.00041175   avg weight        3.3075
# epoch     33  total error   0.00040509   avg weight        3.3202
# epoch     34  total error   0.00041212   avg weight        3.3121
# epoch     35  total error   0.00041186   avg weight        3.2967
# epoch     36  total error   0.00040532   avg weight         3.285
# epoch     37  total error   0.00041162   avg weight        3.2722
# epoch     38  total error   0.00041137   avg weight        3.2849
# epoch     39  total error   0.00041158   avg weight        3.2861
# epoch     40  total error   0.00041116   avg weight        3.3582
# epoch     41  total error   0.00041068   avg weight        3.3781
# epoch     42  total error   0.00041167   avg weight        3.3924
# epoch     43  total error   0.00041166   avg weight        3.4176
# epoch     44  total error   0.00040728   avg weight        3.4539
# epoch     45  total error   0.00040679   avg weight        3.5044
# epoch     46  total error    0.0004107   avg weight        3.5572
# epoch     47  total error   0.00040673   avg weight         3.501
# epoch     48  total error    0.0004075   avg weight        3.4816
# epoch     49  total error    0.0004063   avg weight        3.4557
# Finished training.  total seconds =
#  20303.495007

# %%
# Disaggregate!
print("Starting disaggregation...")
net.reset()
estimates = pd.DataFrame(columns=appliances.columns, index=appliances.index)
for date, mains_value in mains.iteritems():
    estimates.loc[date] = net.activate(mains_value)
# Out:
# Starting disaggregation...

# %%
estimates.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
appliances.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
